# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('final_data.csv')

# %%
a = data[data['symbol']=='NFLX']

# %%
a[a['Date']<='2019-12-31'].groupby('Date').agg('mean')
# Out:
# C:\Users\12364\AppData\Local\Temp\ipykernel_45276\2917741378.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a[a['Date']<='2019-12-31'].groupby('Date').agg('mean')
#               Unnamed: 0  Pctchange        Open        High         Low  \
# Date
# 2017-01-03  2.263357e+06   0.015060  127.489998  130.169998  126.550003
# 2017-01-04  2.263197e+06   0.020043  129.220001  132.750000  128.899994
# 2017-01-05  2.262966e+06  -0.007647  132.080002  133.880005  129.809998
# 2017-01-06  2.262679e+06  -0.004031  131.479996  131.990005  129.889999
# 2017-01-09  2.262447e+06  -0.010513  131.270004  132.220001  129.289993
# ...                  ...        ...         ...         ...         ...
# 2019-12-24  1.964032e+06  -0.005888  334.600006  336.459991  332.010010
# ...
